# %%
# In this we will learn about Connecting callback functions

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
###############
## VARIABLES ##
###############

# True while Mouse button down, False while Mouse button up

Drawing = False
ix, iy = -1, -1

##############
## FUNCTION ##
##############

def draw_rectangle(event,x,y,flgas,param):
    global Drawing, ix, iy
    
    if event == cv2.EVENT_LBUTTONDOWN:
        Drawing = True
        ix, iy = x, y
    
    elif event == cv2.EVENT_MOUSEMOVE:
        if Drawing == True:
            cv2.rectangle(img, (ix, iy), (x, y), (255,255,0), -1)
    
    elif event == cv2.EVENT_LBUTTONUP:
        Drawing = False
        cv2.rectangle(img, (ix, iy), (x, y), (255,255,0), -1)        

#######################
## SHOWING THE IMAGE ##
#######################

img = np.zeros((512,512,3))

cv2.namedWindow(winname = 'my_drawing')
cv2.setMouseCallback('my_drawing', draw_rectangle)

while True:
    
    cv2.imshow('my_drawing', img)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break
        
cv2.destroyAllWindows()
# Out:
# Warning: Ignoring XDG_SESSION_TYPE=wayland on Gnome. Use QT_QPA_PLATFORM=wayland to run on Wayland anyway.
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
#
# QObject::moveToThread: Current thread (0x243df30) is not the object's thread (0x24f4590).
# Cannot move to target thread (0x243df30)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 40
#      36 cv2.setMouseCallback('my_drawing', draw_rectangle)
#      38 while True:
# ---> 40     cv2.imshow('my_drawing', img)
#      42     if cv2.waitKey(20) & 0xFF == 27:
#      43         break
#
# error: OpenCV(4.7.0) /io/opencv/modules/highgui/src/precomp.hpp:155: error: (-215:Assertion failed) src_depth != CV_16F && src_depth != CV_32S in function 'convertToShow'
